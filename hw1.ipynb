# %%
val1 = float(input("Please enter your first value: "))
val2 = float(input("Please enter your Second value: "))
val3 = float(input("Please enter your Third value: "))
val4 = float(input("Please enter your Fourth value: "))
val5 = float(input("Please enter your Fifth value: "))
print(type(val1),type(val2),type(val3),type(val4),type(val5))
values = {"First value" : val1, "Second value" : val2, "Third value" : val3, "Fourth value" : val4, "Fifth value" : val5 }
print(values)
