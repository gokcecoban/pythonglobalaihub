# %%
first_name = input("Your Name: ")
last_name = input("Your Last Name: ")
age = int(input("Your Age: "))
dateofBirth = int(input("Date of Birth(Just year): "))

infoOfuser = [first_name, last_name, age, dateofBirth]

for i in infoOfuser : 
    print(i)
if 0 < age < 18 :
    print("You can't go out it is too dangerous")
elif age >= 18 :
    print("You can go out to the street.")
else :
    print("Please Write A Sensible Age")
